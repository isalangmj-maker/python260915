# %%
# DemoPanda.ipynd 저장
# %matplotlib inline
import pandas as pd
import matplotlib.pylab as plt
import numpy as np

plt.plot(np.arange(10))
#셀단위로 실행 : shift + enter

# %%
from pandas import Series, DataFrame
#시리즈 객체 생성
myCampus = Series([31500, 31300, 31000, 31200, 31300, 31400])
myCampus
# Out:
# 0    31500
# 1    31300
# 2    31000
# 3    31200
# 4    31300
# 5    31400
# dtype: int64

# %%
myCampus = Series([31500, 31300, 31000, 31200, 31300, 31400],
    index=["2026-09-15","2026-09-16","2026-09-17","2026-09-18","2026-09-19",
    "2026-09-20"])
myCampus
# Out:
# 2026-09-15    31500
# 2026-09-16    31300
# 2026-09-17    31000
# 2026-09-18    31200
# 2026-09-19    31300
# 2026-09-20    31400
# dtype: int64

# %%
myCampus["2026-09-16"]
# Out:
# np.int64(31300)

# %%
data = { "foreigner":[1, 2, 3, 4, 5, 6], 
         "sratio":[10, 20, 30, 40, 50, 60], 
         "org":[100, 200, 300, 400, 500, 600], 
         "sprice":[1, 2, 3, 4, 5, 6], 
         "private":[10, 20, 30, 40, 50, 60] }

data
# Out:
# {'foreigner': [1, 2, 3, 4, 5, 6],
#  'sratio': [10, 20, 30, 40, 50, 60],
#  'org': [100, 200, 300, 400, 500, 600],
#  'sprice': [1, 2, 3, 4, 5, 6],
#  'private': [10, 20, 30, 40, 50, 60]}

# %%
frame = DataFrame(data)
print(type(frame))
# Out:
# <class 'pandas.DataFrame'>

# %%
frame
# Out:
#    foreigner  sratio  org  sprice  private
# 0          1      10  100       1       10
# 1          2      20  200       2       20
# 2          3      30  300       3       30
# 3          4      40  400       4       40
# 4          5      50  500       5       50
# 5          6      60  600       6       60

# %%
frame2 = DataFrame(data, 
    columns=["foreigner", "private", "sratio", "org", "sprice"])
frame2
# Out:
#    foreigner  private  sratio  org  sprice
# 0          1       10      10  100       1
# 1          2       20      20  200       2
# 2          3       30      30  300       3
# 3          4       40      40  400       4
# 4          5       50      50  500       5
# 5          6       60      60  600       6

# %%
frame2["private"]
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# Name: private, dtype: int64

# %%
#색인을 날짜시간기반으로 변경한 경우 
frame2 = DataFrame(data, 
    columns=["foreigner", "private", "sratio", "org", "sprice"],
    index=["2026-09-15","2026-09-16","2026-09-17","2026-09-18",
        "2026-09-19","2026-09-20"])
frame2
# Out:
#             foreigner  private  sratio  org  sprice
# 2026-09-15          1       10      10  100       1
# 2026-09-16          2       20      20  200       2
# 2026-09-17          3       30      30  300       3
# 2026-09-18          4       40      40  400       4
# 2026-09-19          5       50      50  500       5
# 2026-09-20          6       60      60  600       6

# %%
frame2["private"]
# Out:
# 2026-09-15    10
# 2026-09-16    20
# 2026-09-17    30
# 2026-09-18    40
# 2026-09-19    50
# 2026-09-20    60
# Name: private, dtype: int64

# %%
#수평데이터 슬라이싱
frame2.loc["2026-09-17"]
# Out:
# foreigner      3
# private       30
# sratio        30
# org          300
# sprice         3
# Name: 2026-09-17, dtype: int64

# %%
#데이터 전치
frame2.T
# frame2.transpose
# Out:
#            2026-09-15  2026-09-16  2026-09-17  2026-09-18  2026-09-19  \
# foreigner           1           2           3           4           5
# private            10          20          30          40          50
# sratio             10          20          30          40          50
# org               100         200         300         400         500
# sprice              1           2           3           4           5
#
#            2026-09-20
# foreigner           6
# private            60
# sratio             60
# org               600
# sprice              6

# %%
# !type c:\work\ex1.csv
# Out:
# id, name, price, description
# 1, iphone, 1990000, iphone 17
# 2, android, 1590000, samsung phone
# 3, winphone, 850000, microsoft winphone

# %%
frame = pd.read_csv("c:\\work\\ex1.csv")
frame
# Out:
#    id       name    price           description
# 0   1     iphone  1990000            iphone 17
# 1   2    android  1590000         samsung phone
# 2   3   winphone   850000   microsoft winphone

# %%
#컬럼이 없는 데이터
# !type c:\work\ex2.csv
# Out:
# 1, iphone, 1990000, iphone 17
# 2, android, 1590000, samsung phone
# 3, winphone, 850000, microsoft winphone

# %%
# 컬럼명이 없으면 첫행이 컬럼으로 들어감
frame = pd.read_csv("c:\\work\\ex2.csv")
frame
# Out:
#    1     iphone   1990000            iphone 17
# 0  2    android   1590000         samsung phone
# 1  3   winphone    850000   microsoft winphone

# %%
frame2 = pd.read_csv("c:\\work\\ex2.csv", 
    names=["id","name","price","desc"])
frame2
# Out:
#    id       name    price                  desc
# 0   1     iphone  1990000            iphone 17
# 1   2    android  1590000         samsung phone
# 2   3   winphone   850000   microsoft winphone

# %%
# !type c:\work\ex3.TXT
# Out:
# data1 data2 data3
# 1.2     2.3     1.3
# 0.1     1.5     2.5
# 3.1     3.2     3.3

# %%
# data3 = pd.read_table('c:\work\ex3.txt', sep='\s+')
# 특수문자 r:raw string notation
data3 = pd.read_table(r'c:\work\ex3.txt', sep=r'\s+')
data3
# Out:
#    data1  data2  data3
# 0    1.2    2.3    1.3
# 1    0.1    1.5    2.5
# 2    3.1    3.2    3.3

# %%
import matplotlib.pyplot as plt
#엑셀 파일을 로딩
dfExcel = pd.read_excel(r"c:\work\demo.xlsx","Sheet1")
# dfExcel
#그림판 생성
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,4)
ax1.hist(dfExcel["나이"], bins=7)
ax2.hist(dfExcel["수입"], bins=7)
# Out:
# (array([3., 1., 4., 0., 0., 1., 1.]),
#  array([ 40.        ,  98.57142857, 157.14285714, 215.71428571,
#         274.28571429, 332.85714286, 391.42857143, 450.        ]),
#  <BarContainer object of 7 artists>)
